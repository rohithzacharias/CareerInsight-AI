# %%
import pandas as pd 
pd.set_option("display.max_columns", None)
placement_df = pd.read_csv(r"C:\Users\rohit\Documents\CareerInsight AI Student Placement Prediction & Analytics Platform\data\raw\Indian_Student_Placement_Dataset_2025.csv")

# %%
salary_df = pd.read_csv(r"C:\Users\rohit\Documents\CareerInsight AI Student Placement Prediction & Analytics Platform\data\raw\ai_job_salary_dataset_10k.csv")

# %%
skill_df = pd.read_csv(r"C:\Users\rohit\Documents\CareerInsight AI Student Placement Prediction & Analytics Platform\data\raw\DMA DATASET.csv")

# %%
feature_df = placement_df.copy()

# %%
feature_df["overall_skill_score"] = (
    feature_df["coding_skills"] +
    feature_df["communication_skills"] +
    feature_df["aptitude_score"]
) / 3

# %%
feature_df["academic_performance_index"] = (
    feature_df["cgpa"] * 10
    - feature_df["backlogs"] * 5
)

# %%
feature_df["profile_strength"] = (
    feature_df["internships"]
    + feature_df["projects"]
    + feature_df["certifications"]
)

# %%
feature_df["profile_development_score"] = (
    feature_df["internships"] +
    feature_df["projects"] +
    feature_df["certifications"]
)

# %%
feature_df[[
    "internships",
    "projects",
    "certifications",
    "profile_development_score"
]].head()
# Out:
#    internships  projects  certifications  profile_development_score
# 0            2         0               2                          4
# 1            0         4               5                          9
# 2            0         1               1                          2
# 3            0         4               4                          8
# 4            1         4               2                          7

# %%
feature_df["overall_skill_score"] = (
    feature_df["coding_skills"] +
    feature_df["communication_skills"] +
    feature_df["aptitude_score"]
) / 3

# %%
feature_df["academic_performance_index"] = (
    feature_df["cgpa"] * 10
    - feature_df["backlogs"] * 5
)

# %%
feature_df["profile_strength"] = (
    feature_df["internships"] +
    feature_df["projects"] +
    feature_df["certifications"]
)

# %%
feature_df[
    [
        "overall_skill_score",
        "academic_performance_index",
        "profile_strength"
    ]
].head()
# Out:
#    overall_skill_score  academic_performance_index  profile_strength
# 0            24.333333                        74.0                 4
# 1            30.333333                        76.0                 9
# 2            19.333333                        51.2                 2
# 3            19.333333                        80.1                 8
# 4            28.333333                        81.2                 7

# %%
feature_df.head()
# Out:
#    student_id  gender  age degree      branch  cgpa  backlogs  internships  \
# 0           1    Male   20     BE  Mechanical  8.40         2            2
# 1           2  Female   20  BTech  Electrical  8.60         2            0
# 2           3    Male   22    BCA  Electrical  6.62         3            0
# 3           4    Male   24    BCA          DS  8.01         0            0
# 4           5    Male   24    BCA  Electrical  9.12         2            1
#
#    certifications  coding_skills  communication_skills  aptitude_score  \
# 0               2              1                     3              69
# 1               5              1                     9              81
# 2               1              1                     7              50
# 3               4              4                     7              47
# 4               2              4                     4              77
#
#    projects  placed company_type  package_lpa  overall_skill_score  \
# ...

# %%
feature_df.columns.tolist()
# Out:
# ['student_id',
#  'gender',
#  'age',
#  'degree',
#  'branch',
#  'cgpa',
#  'backlogs',
#  'internships',
#  'certifications',
#  'coding_skills',
#  'communication_skills',
#  'aptitude_score',
#  'projects',
#  'placed',
#  'company_type',
#  'package_lpa',
#  'overall_skill_score',
#  'academic_performance_index',
#  'profile_strength',
#  'profile_development_score']

# %%
# Keep raw data immutable. The engineered copy is saved in data/processed below.
print("Raw dataset left unchanged.")
# Out:
# Feature engineered dataset saved successfully!

# %%
feature_df.to_csv(
    "../data/processed/student_placement_feature_engineered.csv",
    index=False
)

print("Processed dataset saved successfully!")
# Out:
# Processed dataset saved successfully!
