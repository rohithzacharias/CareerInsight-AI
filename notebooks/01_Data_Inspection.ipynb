# %%
import pandas as pd
import numpy as np

# Display all columns
pd.set_option("display.max_columns", None)
print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
placement_df = pd.read_csv(r"C:\Users\rohit\Documents\CareerInsight AI Student Placement Prediction & Analytics Platform\data\raw\Indian_Student_Placement_Dataset_2025.csv")

# %%
salary_df = pd.read_csv(r"C:\Users\rohit\Documents\CareerInsight AI Student Placement Prediction & Analytics Platform\data\raw\ai_job_salary_dataset_10k.csv")

# %%
skill_df = pd.read_csv(r"C:\Users\rohit\Documents\CareerInsight AI Student Placement Prediction & Analytics Platform\data\raw\DMA DATASET.csv")

# %%
print("Placement Dataset:", placement_df.shape)
print("Salary Dataset:", salary_df.shape)
print("Skill Dataset:", skill_df.shape)
# Out:
# Placement Dataset: (12000, 16)
# Salary Dataset: (10000, 7)
# Skill Dataset: (500, 15)

# %%
placement_df.head()
salary_df.head()
skill_df.head()
# Out:
#               Name                    email_id  Year      Current Course  \
# 0   Iorgo Hakonsen    ihakonsen0@instagram.com   2nd                 MBA
# 1    Emmery Duffyn    eduffyn1@dailymotion.com  Final                BBA
# 2  Susanetta Wards            swards2@digg.com    2nd  B.Sc Data Science
# 3    Amanda Gussin           agussin3@webs.com   2nd           M.Tech AI
# 4   Carlina Beaven  cbeaven4@timesonline.co.uk   1st           B.Tech IT
#
#                        Technical Skills      Programming Languages  Rating  \
# 0             Cybersecurity, Blockchain              Python, R, C#       2
# 1                 SQL, Machine Learning                      R, Go       3
# 2                   Cybersecurity, Java                 JavaScript       4
# 3               Blockchain, Python, SQL                 Python, C#       3
# 4  Blockchain, Machine Learning, Python                   Java, Go       4
#
#                                     Soft Skills  Rating.1  Projects  \
# ...

# %%
#inspect the dataset 
print("=" * 60)
print("PLACEMENT DATASET INFORMATION")
print("=" * 60)

print("\nShape:")
print(placement_df.shape)

print("\nColumns:")
print(placement_df.columns.tolist())

print("\nDataset Info:")
placement_df.info()

print("\nMissing Values:")
print(placement_df.isnull().sum())

print("\nDuplicate Rows:")
print(placement_df.duplicated().sum())

print("\nNumerical Summary:")
display(placement_df.describe())

print("\nCategorical Summary:")
display(placement_df.describe(include='object'))
# Out:
# ...
# PLACEMENT DATASET INFORMATION
# ...
#
# Shape:
# (12000, 16)
#
# Columns:
# ['student_id', 'gender', 'age', 'degree', 'branch', 'cgpa', 'backlogs', 'internships', 'certifications', 'coding_skills', 'communication_skills', 'aptitude_score', 'projects', 'placed', 'company_type', 'package_lpa']
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   student_id            12000 non-null  int64
#  1   gender                12000 non-null  object
#  2   age                   12000 non-null  int64
#  3   degree                12000 non-null  object
#  4   branch                12000 non-null  object
#  5   cgpa                  12000 non-null  float64
#  6   backlogs              12000 non-null  int64
#  7   internships           12000 non-null  int64
#  8   certifications        12000 non-null  int64
# ...

# %%
#Repeat for the Salary Dataset

print("=" * 60)
print("SALARY DATASET INFORMATION")
print("=" * 60)

print(salary_df.columns.tolist())
salary_df.info()
salary_df.isnull().sum()
salary_df.duplicated().sum()

display(salary_df.describe())
display(salary_df.describe(include='object'))
# Out:
# ...
# SALARY DATASET INFORMATION
# ...
# ['id', 'job_role', 'country', 'experience_level', 'salary_usd', 'skills', 'company_type']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                10000 non-null  int64
#  1   job_role          10000 non-null  object
#  2   country           10000 non-null  object
#  3   experience_level  10000 non-null  object
#  4   salary_usd        10000 non-null  int64
#  5   skills            10000 non-null  object
#  6   company_type      10000 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 547.0+ KB
#                 id     salary_usd
# count  10000.00000   10000.000000
# mean    5000.50000   95210.201300
# std     2886.89568   58450.013652
# min        1.00000    8023.000000
# 25%     2500.75000   45051.000000
# 50%     5000.50000   81579.000000
# ...

# %%
#Repeat for the Skill Dataset
print("=" * 60)
print("SKILL DATASET INFORMATION")
print("=" * 60)

print(skill_df.columns.tolist())
skill_df.info()
skill_df.isnull().sum()
skill_df.duplicated().sum()

display(skill_df.describe())
display(skill_df.describe(include='object'))
# Out:
# ...
# SKILL DATASET INFORMATION
# ...
# ['Name', 'email_id', 'Year ', 'Current Course', 'Technical Skills', '     Programming Languages', 'Rating', 'Soft Skills', 'Rating.1', ' Projects', 'Career Interest', 'Challenges ', 'Support required', 'Unnamed: 13', ' Method']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Name                        500 non-null    object
#  1   email_id                    500 non-null    object
#  2   Year                        500 non-null    object
#  3   Current Course              500 non-null    object
#  4   Technical Skills            500 non-null    object
#  5        Programming Languages  500 non-null    object
#  6   Rating                      500 non-null    int64
#  7   Soft Skills                 500 non-null    object
# ...

# %%
placement_df.columns.tolist()
# Out:
# ['student_id',
#  'gender',
#  'age',
#  'degree',
#  'branch',
#  'cgpa',
#  'backlogs',
#  'internships',
#  'certifications',
#  'coding_skills',
#  'communication_skills',
#  'aptitude_score',
#  'projects',
#  'placed',
#  'company_type',
#  'package_lpa']

# %%
salary_df.columns.tolist()
# Out:
# ['id',
#  'job_role',
#  'country',
#  'experience_level',
#  'salary_usd',
#  'skills',
#  'company_type']

# %%
skill_df.columns.tolist()
# Out:
# ['Name',
#  'email_id',
#  'Year ',
#  'Current Course',
#  'Technical Skills',
#  '     Programming Languages',
#  'Rating',
#  'Soft Skills',
#  'Rating.1',
#  ' Projects',
#  'Career Interest',
#  'Challenges ',
#  'Support required',
#  'Unnamed: 13',
#  ' Method']
